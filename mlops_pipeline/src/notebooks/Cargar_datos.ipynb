# %% [markdown]
# # Cargar datos
#
# Este notebook no se utiliza normalmente en el proceso de creación
# de un modelo dado que nuestra data deberá estar en el DWH o Datalake de la empresa
# como resultado de un proceso diferente que materialice nuestra información en una tabla.
# Sin embargo, para este caso, se utiliza un dataset no productivo de ejemplo en .csv.

# %%
import pandas as pd

# %%
df = pd.read_csv("../../alzheimers_disease_data.csv")
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...
